# %% [markdown]
# # Assignment 1
#
# This assignment will involve the creation of a spellchecking system and an evaluation of its performance. You may use the code snippets provided in Python for completing this or you may use the programming language or environment of your choice
#
# Please start by downloading the corpus `holbrook-tagged.dat` from Blackboard
#
# You may process the file using the following code. You should inspect the code to ensure that you understand its operation.
#
# _Note:  [the "yield" statement](http://stackoverflow.com/questions/231767/what-does-the-yield-keyword-do-in-python#231855)  makes a function into an "iterator"_
#
# _Note: There are snippets of code to help you build your answers. These are provided as a guide and do not need to be followed exactly.
# Comments like _"# Write your code here."_ indicate where you could write your code._

# %%
from nltk.tokenize.regexp import WordPunctTokenizer

tokenizer = WordPunctTokenizer()

class SpellingSentence:
    """Store a sentence in original form and any spelling errors."""
    def __init__(self, text, spans, error_spans, corrections):
        """Constructor parameters are as follows:
        text: the original sentence.
        spans: an iterable that returns a span (start and end indices) for each word in the text.
        error_spans: a list of spans for mis-spelled words.
        corrections: a list of corresponding correctly spelled words.
        """
        self.text = text
        self.spans = list(spans)
        self.error_spans = error_spans
        self.corrections = corrections
        
    def __str__(self):
        return self.text
        
    def tokens_with_errors(self):
        """Returns an iterator over the original (possibly mis-spelled) words as strings."""
        for x, y in self.spans:
            yield self.text[x:y]
 
    def tokens_corrected(self):
        """Returns an iterator over the corrected words as strings."""
        token_spans = []
        for s1 in self.spans:
            is_not_in_error_span = True
            for s2 in self.error_spans:
                is_not_in_error_span = (is_not_in_error_span and
                                        not (s1[0] >= s2[0] and s1[1] <= s2[1]))
            if is_not_in_error_span:
                token_spans.append(s1)
                    
        token_spans = token_spans + self.error_spans
        token_spans = sorted(token_spans, key = lambda s1: s1[0])
        
        for x,y in token_spans:
            if (x, y) in self.error_spans:
                yield self.corrections[self.error_spans.index((x, y))]
            else:
                yield self.text[x:y]
    
    def errors(self):
        """Returns an iterator over the mis-spelled words as strings."""
        for x, y in self.error_spans:
            yield self.text[x:y]
    

def read_sentence(sentence):
    """Reads a sentence from the holbrook spelling corpus (as text), 
    returning a SpellingSentence instance for that senetence."""
    error_spans = []
    corrections = []
    while "<ERR" in sentence:
        i = sentence.index("<ERR")
        j = sentence.index(">")
        correction = sentence[(i+10):j]
        k = sentence.index("</ERR>")
        if i > 0:
            sentence = sentence[:(i-1)] + sentence[(j+1):(k-1)] + sentence[(k+6):]
        else:
            sentence = sentence[(j+1):(k-1)] + sentence[(k+6):]
        error_spans.append((i, k - (j - i  + 3)))
        corrections.append(correction)
    return SpellingSentence(sentence, tokenizer.span_tokenize(sentence), 
                            error_spans, corrections)
       
    

        
# Example usage:
ss = read_sentence("My <ERR targ=sister> siter </ERR> <ERR targ=goes> go </ERR> to Tonbury.")

print(list(ss.tokens_with_errors()))
print(list(ss.tokens_corrected()))
print(ss.error_spans)
print(ss.spans)
print(list(ss.errors()))
print(ss.corrections)
# Out:
# ['My', 'siter', 'go', 'to', 'Tonbury', '.']
# ['My', 'sister', 'goes', 'to', 'Tonbury', '.']
# [(3, 8), (9, 11)]
# [(0, 2), (3, 8), (9, 11), (12, 14), (15, 22), (22, 23)]
# ['siter', 'go']
# ['sister', 'goes']

# %% [markdown]
# You can load all the data as follows:
#
# _Note: you need to have downloaded the file _"holbrook-tagged.dat"_ from blackboard into your notebook directory._

# %%
data = [read_sentence(line) for line in open("holbrook-tagged.dat").readlines()]

test = data[1:100]
train = data[101:]

#train = [d.text for d in train]
#print(train_set)
test_set = [d.text for d in test]
#print(test_set)
#test

# %% [markdown]
# \## **Task 1**:
# Calculate the frequency, *ignoring case*, of all words and bigrams (sequences of two words) satisfying the following assertions from the corrected *training* sentences:

# %%
import numpy as np
from nltk import bigrams

def unigram(word):
    # ** Don't go through the whole corpus every time! Better to pre-compute values and look up here (-1)
    z=0
    for each_line in train:
        z+= str(each_line).lower().split(" ").count(word)
    return z

from collections import Counter
from nltk.collocations import *

def bigram(words):
    d={}
    s={}
    z=0
    words_bi = tuple(words.split(" "))
    #words_bi = words
    #print(words_bi)
    # ** You generate all bigrams to calculate one frequency. Better to have precomputed (-1)
    for each_line in train:
        d= list(bigrams(str(each_line).lower().split(" ")))
        s=Counter(d)
        z=z+s[words_bi] 
                                  
    return z

uni=unigram("the") 
print("Frequency of the unigram word 'the' :", uni)
bi =bigram("it will")
print("Frequency of the bigram words 'it will' :",bi)
# Out:
# Frequency of the unigram word 'the' : 1529
# Frequency of the bigram words 'it will' : 9

# %% [markdown]
# ## **Task 2**:
# Using the following as a basis find all words that have the minimal edit distance from a given word (i.e., there does not exist another word with lower edit distance in the corrected training corpus):
#
# *Note: [Edit distance](https://en.wikipedia.org/wiki/Edit_distance) is a way of quantifying how dissimilar two strings are to one another by counting the minimum number of operations required to transform one string into the other*

# %%
from nltk.metrics.distance import edit_distance

# Edit distance returns the number of changes to transform one word to another
print(edit_distance("hello", "hi"))

all_words = set()

for line in train:
    all_words.update(line.tokens_corrected())
# Out:
# 4

# %%
import numpy as np

def get_candidates(token):
    ed = []
    d1 = []

    for t in all_words:
        ed.append(edit_distance(token, t))
    min_ed = min(ed)
    
    # ** you should make this conversion earlier and use all_l instead of all_words in the above loop also (-1)
    # ** this is because you cannot rely on the iteration order of sets (like all_words)
    all_1=list(all_words)
    # ** why are you converting first to a list, then an array? Use one or the other, probably a list here
    myarray = np.asarray(all_1)
    for i in range(len(ed)):
        if ed[i] == min_ed:
            d1.append(myarray[i])
        
    return d1


        
# get_candidates() should find the following
#assert get_candidates("calld") = ['calls', 'call', 'called']
print("Words with minimal edit distance for the word 'calld' are : ",get_candidates("calld"))
# Out:
# Words with minimal edit distance for the word 'calld' are :  ['called', 'call', 'calls']

# %% [markdown]
# ## **Task 3**:
# Write a function that corrects spelling based on n-gram language model probabilities. It should work as follows
#
# * Check if each word is the same as a correctly spelled word from the corpus
# * If not, find the corpus words with minimum edit distance to that word
# * If multiple corpus words have the same edit distance
#     * Choose the most likely word based on the bigram probability, recall:
#         * $p(w_n|w_{n-1}) = \frac{c(w_{n-1}w_n)}{c(w_{n-1}\cdot)}$ where $c()$ is the count in the corpus
#     * If the bigram probability does not exist (or the spelling error is in the first word), use the unigram probability, recall:
#         * $p(w_n) = \frac{c(w_n)}{N}$ where $N$ is the total number of *tokens* (not types) in the corpus

# %%
# ** you need to reset token_incorrect INSIDE the function, else it just keeps getting bigger with each call! (-1)
token_incorrect = []
def correct(tokens):
    for token in tokens:
        j=1
        for i in all_words:
            if token == i:
                j=0
        if j==1:
            token_incorrect.append(token)
    #print("Incorrect token is : ", token_incorrect)             
    return token_incorrect
    # ** Why do you end the function here! (-1)

is_misspelled=correct(["so", "they", "calld", "it", "the", "murder", "car"])

test_ex = ["so", "they", "calld", "it", "the", "murder", "car"]
#test_ex = ['NIGEL', 'THRUSH', 'page', '48']
print("Words mispelled : ", is_misspelled)

# if is_misspelled(token):
# ** youre converting a list is_misspelled to a string - you should get_candidates() for each element of it! (-2)
# ** all the code below should be in a loop over words in is_misspelled...
candidates = get_candidates(str(is_misspelled))
print("Candidates with minimum edit distance :",candidates)
error_index=test_ex.index(is_misspelled[0])

from operator import itemgetter
if len(candidates) > 1:
    # ** is_misspelled is a list, text_ex[0] a string ... this if is always true!! (-1)
    if is_misspelled != test_ex[0]:
        
         # Find candidate with highest bigram value
        probability_bigram = {}
        for i in range(len(candidates)):
            bigram_words= test_ex[error_index-1] + " " + candidates[i]
            #print(bigram_words)
            probability_bigram[i] = bigram(bigram_words)/unigram(test_ex[error_index-1])
            
        # ** an unusual way to get there, but it works! 
        p=Counter(probability_bigram).most_common()[0]
        
        print("Corrected word with high bigram probability :", candidates[p[0]])
        test_ex[error_index] = candidates[p[0]]
        print("Corrected sentence:", test_ex)
    else:
        # Find candidate with highest unigram value
        probability_unigram = {}
        for i in range(len(candidates)):
            unigram_words= candidates[i]
            probability_unigram[i] = unigram(unigram_words)/len(train)
        q=Counter(probability_unigram).most_common()[0]
        print("Corrected word with high unigram probability :",candidates[q[0]])
        # yield best_candidate
        test_ex[error_index] = candidates[q[0]]
        print(test_ex)
               
# ** you should have implemented this as a function, like in the cell in Task 4 
# ** I'd take 2 off for that, except you did put the function in for Task 4, so only (-1)
# Out:
# Words mispelled :  ['calld']
# Candidates with minimum edit distance : ['call', 'calls', 'called']
# Corrected word with high bigram probability : called
# Corrected sentence: ['so', 'they', 'called', 'it', 'the', 'murder', 'car']

# %% [markdown]
# ## **Task 4**:
# Using the test corpus evaluate the *accuracy* of your method, i.e., how many words from your systems output match the corrected sentence (you should count words that are already spelled correctly and not changed by the system).

# %%
# ** I can't figure this out. You should have done task 3 as a function 
# ** This should have been your answer for Task 3.. 
def acorrect(tokens):
    token_incorrect = []
    print(tokens)
    for token in tokens:
        j=1
        for i in all_words:
            if token == i:
                j=0
        if j==1:
            token_incorrect.append(token)
    print("Incorrect token is : ", token_incorrect)             
    #return token_incorrect


    #is_misspelled=acorrect(["so", "thy", "calld", "it", "the", "murder", "car"])
    is_misspelled=token_incorrect
    #test_ex = ["so", "thy", "calld", "it", "the", "murder", "car"]
    test_ex = tokens
    print("Words mispelled : ", is_misspelled)

    for i in range(len(is_misspelled)):
        # if is_misspelled(token):
        error_index=test_ex.index(is_misspelled[i])        
        print("Error Index : ",error_index, ":",is_misspelled[i])
        candidates = get_candidates(str(is_misspelled[i]))
        print("Candidates with minimum edit distance :",candidates)
        
        from operator import itemgetter
        if len(candidates) > 1:
            print("in IF condition Greater Candidate :")
            if error_index != 0:
                print("in IF condition - calculate Bigram :",is_misspelled[i])
                # Find candidate with highest bigram value
                probability_bigram = {}
                for i in range(len(candidates)):
                    print("Previous Error value :",test_ex[error_index-1])
                    bigram_words= test_ex[error_index-1] + " " + candidates[i]
                    print("Bi-gram words :",bigram_words)                    
                    #if unigram(test_ex[error_index-1]) > 0:
                    #print("in Uni gram Condition satisfied....")
                    unigramCount = unigram(test_ex[error_index-1])
                    if unigramCount == 0:
                        print("Unigram Count :",unigramCount)
                    else :                        
                        probability_bigram[i] = bigram(bigram_words)/unigram(test_ex[error_index-1])
                        print("prob for each bigram:",probability_bigram[i]) 
                        p=Counter(probability_bigram).most_common()[0]   
                        print("Corrected word with high bigram probability :", candidates[p[0]])
                        test_ex[error_index] = candidates[p[0]]
                        print("Corrected sentence:", test_ex)
                        
                print("Out of FOR LOOP")    
                             
            else:
                print("in ELSE condition - Unigram :",is_misspelled[i])
                # Find candidate with highest unigram value
                probability_unigram = {}
                for i in range(len(candidates)):
                    unigram_words= candidates[i]
                    probability_unigram[i] = unigram(unigram_words)/len(train)
                q=Counter(probability_unigram).most_common()[0]
                print("Corrected word with high unigram probability :",candidates[q[0]])
                # yield best_candidate
                test_ex[error_index] = candidates[q[0]]
                print(test_ex)
        else:
            print("in ELSE condition NO Candidates :")
            test_ex[error_index] = candidates[0]
            print(test_ex)
    return test_ex

# %%
is_misspelled_test = []
# ** why not just use provided tokenisations: [d.tokens_with_errors() for d in test] 
# ** why not just use provided tokenisations: [d.tokens_corrected() for d in test] (-1)
test_set = [d.text for d in test]
#is_misspelled_train=correct(train_set.split(" "))
Words_mispelled1=[]
#print("Words mispelled : ", is_misspelled_train)
for sentence in range(len(test_set)):
    s=test_set[sentence]
    line = s.rstrip('\r\n').replace(".","").strip() 
    if len(line) != 0:
        is_misspelled_test = line.split(" ")
        Words_mispelled1.append(acorrect(is_misspelled_test))

print(Words_mispelled1)

#for i in Words_mispelled1:
    #candidates = get_candidates(str(i))
#print("Candidates with minimum edit distance :",candidates)
# Out:
# ['NIGEL', 'THRUSH', 'page', '48']
# Incorrect token is :  ['NIGEL', 'THRUSH', '48']
# Words mispelled :  ['NIGEL', 'THRUSH', '48']
# Error Index :  0 : NIGEL
# Candidates with minimum edit distance : ['ROGER', 'WIGGLE', 'DIED', 'JILL']
# in IF condition Greater Candidate :
# in ELSE condition - Unigram : NIGEL
# Corrected word with high unigram probability : ROGER
# ['ROGER', 'THRUSH', 'page', '48']
# Error Index :  1 : THRUSH
# Candidates with minimum edit distance : ['HIS', 'THEN', 'JUST', 'THE', 'ROSE']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : THRUSH
# Previous Error value : ROGER
# Bi-gram words : ROGER HIS
# Unigram Count : 0
# Previous Error value : ROGER
# Bi-gram words : ROGER THEN
# Unigram Count : 0
# Previous Error value : ROGER
# Bi-gram words : ROGER JUST
# Unigram Count : 0
# Previous Error value : ROGER
# Bi-gram words : ROGER THE
# Unigram Count : 0
# Previous Error value : ROGER
# Bi-gram words : ROGER ROSE
# Unigram Count : 0
# Out of FOR LOOP
# Error Index :  3 : 48
# Candidates with minimum edit distance : ['4', '8', '18', '28', '40', '45']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : 48
# Previous Error value : page
# Bi-gram words : page 4
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Previous Error value : page
# Bi-gram words : page 8
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Previous Error value : page
# Bi-gram words : page 18
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Previous Error value : page
# Bi-gram words : page 28
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Previous Error value : page
# Bi-gram words : page 40
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Previous Error value : page
# Bi-gram words : page 45
# prob for each bigram: 0.0
# Corrected word with high bigram probability : 4
# Corrected sentence: ['ROGER', 'THRUSH', 'page', '4']
# Out of FOR LOOP
# ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'siter']
# Incorrect token is :  ['siter']
# Words mispelled :  ['siter']
# Error Index :  9 : siter
# Candidates with minimum edit distance : ['sister']
# in ELSE condition NO Candidates :
# ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister']
# ['My', 'Dad', 'works', 'at', 'Melton']
# Incorrect token is :  []
# Words mispelled :  []
# ['My', 'siter', 'go', 'to', 'Tonbury']
# Incorrect token is :  ['siter']
# Words mispelled :  ['siter']
# Error Index :  1 : siter
# Candidates with minimum edit distance : ['sister']
# in ELSE condition NO Candidates :
# ['My', 'sister', 'go', 'to', 'Tonbury']
# ['My', 'Mum', 'goes', 'out', 'some', 'times']
# Incorrect token is :  []
# Words mispelled :  []
# ['I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'some', 'times', 'on', 'Tuesday', 'night', 'i', 'go', 'to', 'Youth', 'clob']
# Incorrect token is :  ['Tuesday', 'clob']
# Words mispelled :  ['Tuesday', 'clob']
# Error Index :  10 : Tuesday
# Candidates with minimum edit distance : ['Thursday', 'THursday']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : Tuesday
# Previous Error value : on
# Bi-gram words : on Thursday
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Thursday
# Corrected sentence: ['I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'some', 'times', 'on', 'Thursday', 'night', 'i', 'go', 'to', 'Youth', 'clob']
# Previous Error value : on
# Bi-gram words : on THursday
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Thursday
# Corrected sentence: ['I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'some', 'times', 'on', 'Thursday', 'night', 'i', 'go', 'to', 'Youth', 'clob']
# Out of FOR LOOP
# Error Index :  16 : clob
# Candidates with minimum edit distance : ['club']
# in ELSE condition NO Candidates :
# ['I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'some', 'times', 'on', 'Thursday', 'night', 'i', 'go', 'to', 'Youth', 'club']
# ['On', 'thursday', 'nights', 'I', 'go', 'bell', 'ringing', 'on', 'Saturdays', 'I', 'go', 'down', 'to', 'the', 'farm']
# Incorrect token is :  ['thursday', 'ringing', 'Saturdays']
# Words mispelled :  ['thursday', 'ringing', 'Saturdays']
# Error Index :  1 : thursday
# Candidates with minimum edit distance : ['Thursday']
# in ELSE condition NO Candidates :
# ['On', 'Thursday', 'nights', 'I', 'go', 'bell', 'ringing', 'on', 'Saturdays', 'I', 'go', 'down', 'to', 'the', 'farm']
# Error Index :  6 : ringing
# Candidates with minimum edit distance : ['singing']
# in ELSE condition NO Candidates :
# ['On', 'Thursday', 'nights', 'I', 'go', 'bell', 'singing', 'on', 'Saturdays', 'I', 'go', 'down', 'to', 'the', 'farm']
# Error Index :  8 : Saturdays
# Candidates with minimum edit distance : ['Saturday']
# in ELSE condition NO Candidates :
# ['On', 'Thursday', 'nights', 'I', 'go', 'bell', 'singing', 'on', 'Saturday', 'I', 'go', 'down', 'to', 'the', 'farm']
# ['on', 'sundays', 'I', 'go', 'to', 'church']
# Incorrect token is :  ['sundays']
# Words mispelled :  ['sundays']
# Error Index :  1 : sundays
# Candidates with minimum edit distance : ['sunday']
# in ELSE condition NO Candidates :
# ['on', 'sunday', 'I', 'go', 'to', 'church']
# ['I', 'go', 'to', 'bed', 'at', '10', 'o', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Incorrect token is :  ['o', 'wakh', 'o']
# Words mispelled :  ['o', 'wakh', 'o']
# Error Index :  6 : o
# Candidates with minimum edit distance : ['.', '%', 'd', 'i', '?', 'oh', 'To', 'h', '4', "'", 'E', ',', 'So', 'O', 'or', 'on', 'j', '8', 't', 'm', 'K', '`', 'S', '5', 'to', '3', 's', 'p', 'I', 'H', 'B', 'go', '/', 'do', 'a', '6', 'J', 'G', '2', 'Do', '#', 'M', '1', '!', 'No', 'Q', 'A', 'C', ':', '-', ';', ')', 'ow', '9', 'P', 'no', 'so', '7', 'of', 'T', '"', 'V', '(']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : o
# Previous Error value : 10
# Bi-gram words : 10 .
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 %
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 d
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 i
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 ?
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 oh
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 To
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 h
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 4
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 '
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 E
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 ,
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 So
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 O
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 or
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 on
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 j
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 8
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 t
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 m
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 K
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 `
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 S
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 5
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 to
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 3
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 s
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 p
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 I
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 H
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 B
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 go
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 /
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 do
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', '.', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 a
# prob for each bigram: 0.16666666666666666
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 6
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 J
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 G
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 2
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 Do
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 #
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 M
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 1
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 !
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 No
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 Q
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 A
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 C
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 :
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 -
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 ;
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 )
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 ow
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 9
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 P
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 no
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 so
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 7
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 of
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 T
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 "
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 V
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 10
# Bi-gram words : 10 (
# prob for each bigram: 0.0
# Corrected word with high bigram probability : a
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wakh', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Out of FOR LOOP
# Error Index :  9 : wakh
# Candidates with minimum edit distance : ['wash']
# in ELSE condition NO Candidates :
# ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', 'o', 'clock', 'I', 'live', 'in', 'a', 'house']
# Error Index :  13 : o
# Candidates with minimum edit distance : ['.', '%', 'd', 'i', '?', 'oh', 'To', 'h', '4', "'", 'E', ',', 'So', 'O', 'or', 'on', 'j', '8', 't', 'm', 'K', '`', 'S', '5', 'to', '3', 's', 'p', 'I', 'H', 'B', 'go', '/', 'do', 'a', '6', 'J', 'G', '2', 'Do', '#', 'M', '1', '!', 'No', 'Q', 'A', 'C', ':', '-', ';', ')', 'ow', '9', 'P', 'no', 'so', '7', 'of', 'T', '"', 'V', '(']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : o
# Previous Error value : 5
# Bi-gram words : 5 .
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 %
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 d
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 i
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 ?
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 oh
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 To
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 h
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 4
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 '
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 E
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 ,
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 So
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 O
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 or
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 on
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 j
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 8
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 t
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 m
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 K
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 `
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 S
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 5
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 to
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 3
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 s
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 p
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 I
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 H
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 B
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 go
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 /
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 do
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 a
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 6
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 J
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 G
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 2
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 Do
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 #
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 M
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 1
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 !
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 No
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 Q
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 A
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 C
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 :
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 -
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 ;
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 )
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 ow
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 9
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 P
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 no
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 so
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 7
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 of
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 T
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 "
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 V
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Previous Error value : 5
# Bi-gram words : 5 (
# prob for each bigram: 0.0
# Corrected word with high bigram probability : .
# Corrected sentence: ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house']
# Out of FOR LOOP
# ['The', 'house', 'is', 'in', 'the', 'world']
# Incorrect token is :  []
# Words mispelled :  []
# ['I', 'live', 'at', 'Boar', 'Parva', 'it', 'is', 'near', 'Melton', 'and', 'Bridgebrook', 'and', 'Smallerden']
# Incorrect token is :  ['Boar', 'Parva']
# Words mispelled :  ['Boar', 'Parva']
# Error Index :  3 : Boar
# Candidates with minimum edit distance : ['Boat']
# in ELSE condition NO Candidates :
# ['I', 'live', 'at', 'Boat', 'Parva', 'it', 'is', 'near', 'Melton', 'and', 'Bridgebrook', 'and', 'Smallerden']
# Error Index :  4 : Parva
# Candidates with minimum edit distance : ['area', 'Park']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : Parva
# Previous Error value : Boat
# Bi-gram words : Boat area
# Unigram Count : 0
# Previous Error value : Boat
# Bi-gram words : Boat Park
# Unigram Count : 0
# Out of FOR LOOP
# ['The', 'house', 'is', 'white', 'it', 'has', 'stone', 'up', 'the', 'frount', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexeon', 'from', 'Smallerden']
# Incorrect token is :  ['stone', 'frount', 'sexeon']
# Words mispelled :  ['stone', 'frount', 'sexeon']
# Error Index :  6 : stone
# Candidates with minimum edit distance : ['shone', 'store', 'stole']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : stone
# Previous Error value : has
# Bi-gram words : has shone
# prob for each bigram: 0.0
# Corrected word with high bigram probability : shone
# Corrected sentence: ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'frount', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexeon', 'from', 'Smallerden']
# Previous Error value : has
# Bi-gram words : has store
# prob for each bigram: 0.0
# Corrected word with high bigram probability : shone
# Corrected sentence: ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'frount', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexeon', 'from', 'Smallerden']
# Previous Error value : has
# Bi-gram words : has stole
# prob for each bigram: 0.0
# Corrected word with high bigram probability : shone
# Corrected sentence: ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'frount', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexeon', 'from', 'Smallerden']
# Out of FOR LOOP
# Error Index :  9 : frount
# Candidates with minimum edit distance : ['front']
# in ELSE condition NO Candidates :
# ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'front', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexeon', 'from', 'Smallerden']
# Error Index :  18 : sexeon
# Candidates with minimum edit distance : ['sexton']
# in ELSE condition NO Candidates :
# ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'front', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexton', 'from', 'Smallerden']
# ['My', 'Mum', 'is', 'at', 'home', 'She', 'goes', 'to', 'the', 'shop', 'on', 'fridays', 'My', 'Dad', 'goes', 'to', 'work', 'at', 'Smallerden']
# Incorrect token is :  ['fridays']
# Words mispelled :  ['fridays']
# Error Index :  11 : fridays
# Candidates with minimum edit distance : ['Friday']
# in ELSE condition NO Candidates :
# ['My', 'Mum', 'is', 'at', 'home', 'She', 'goes', 'to', 'the', 'shop', 'on', 'Friday', 'My', 'Dad', 'goes', 'to', 'work', 'at', 'Smallerden']
# ['What', 'I', 'do', 'when', 'I', 'get', 'home', 'from', 'school']
# Incorrect token is :  []
# Words mispelled :  []
# ['On', 'monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'BBC', 'and', 'ITV']
# Incorrect token is :  ['monday', 'wach', 'BBC', 'ITV']
# Words mispelled :  ['monday', 'wach', 'BBC', 'ITV']
# Error Index :  1 : monday
# Candidates with minimum edit distance : ['Monday']
# in ELSE condition NO Candidates :
# ['On', 'Monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'BBC', 'and', 'ITV']
# Error Index :  12 : wach
# Candidates with minimum edit distance : ['wash', 'watch', 'each']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : wach
# Previous Error value : I
# Bi-gram words : I wash
# Unigram Count : 0
# Previous Error value : I
# Bi-gram words : I watch
# Unigram Count : 0
# Previous Error value : I
# Bi-gram words : I each
# Unigram Count : 0
# Out of FOR LOOP
# Error Index :  16 : BBC
# Candidates with minimum edit distance : ['ABC']
# in ELSE condition NO Candidates :
# ['On', 'Monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'ABC', 'and', 'ITV']
# Error Index :  18 : ITV
# Candidates with minimum edit distance : ['TV', 'XTV']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : ITV
# Previous Error value : and
# Bi-gram words : and TV
# prob for each bigram: 0.0
# Corrected word with high bigram probability : TV
# Corrected sentence: ['On', 'Monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'ABC', 'and', 'TV']
# Previous Error value : and
# Bi-gram words : and XTV
# prob for each bigram: 0.0
# Corrected word with high bigram probability : TV
# Corrected sentence: ['On', 'Monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'ABC', 'and', 'TV']
# Out of FOR LOOP
# ['I', 'like', 'ITV']
# Incorrect token is :  ['ITV']
# Words mispelled :  ['ITV']
# Error Index :  2 : ITV
# Candidates with minimum edit distance : ['TV', 'XTV']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : ITV
# Previous Error value : like
# Bi-gram words : like TV
# prob for each bigram: 0.0
# Corrected word with high bigram probability : TV
# Corrected sentence: ['I', 'like', 'TV']
# Previous Error value : like
# Bi-gram words : like XTV
# prob for each bigram: 0.0
# Corrected word with high bigram probability : TV
# Corrected sentence: ['I', 'like', 'TV']
# Out of FOR LOOP
# ['We', 'call', 'Anglia', 'ITV']
# Incorrect token is :  ['Anglia', 'ITV']
# Words mispelled :  ['Anglia', 'ITV']
# Error Index :  2 : Anglia
# Candidates with minimum edit distance : ['English']
# in ELSE condition NO Candidates :
# ['We', 'call', 'English', 'ITV']
# Error Index :  3 : ITV
# Candidates with minimum edit distance : ['TV', 'XTV']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : ITV
# Previous Error value : English
# Bi-gram words : English TV
# Unigram Count : 0
# Previous Error value : English
# Bi-gram words : English XTV
# Unigram Count : 0
# Out of FOR LOOP
# ['We', 'have', 'got', 'Anglia', 'like', 'to', 'wach', 'cow', 'Boys']
# Incorrect token is :  ['Anglia', 'wach']
# Words mispelled :  ['Anglia', 'wach']
# Error Index :  3 : Anglia
# Candidates with minimum edit distance : ['English']
# in ELSE condition NO Candidates :
# ['We', 'have', 'got', 'English', 'like', 'to', 'wach', 'cow', 'Boys']
# Error Index :  6 : wach
# Candidates with minimum edit distance : ['wash', 'watch', 'each']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : wach
# Previous Error value : to
# Bi-gram words : to wash
# prob for each bigram: 0.0
# Corrected word with high bigram probability : wash
# Corrected sentence: ['We', 'have', 'got', 'English', 'like', 'to', 'wash', 'cow', 'Boys']
# Previous Error value : to
# Bi-gram words : to watch
# prob for each bigram: 0.0
# Corrected word with high bigram probability : wash
# Corrected sentence: ['We', 'have', 'got', 'English', 'like', 'to', 'wash', 'cow', 'Boys']
# Previous Error value : to
# Bi-gram words : to each
# ...
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of frying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of waving
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of flying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of farming
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of laying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Previous Error value : of
# Bi-gram words : of Waiting
# prob for each bigram: 0.0
# Corrected word with high bigram probability : taking
# Corrected sentence: ['when', 'they', 'came', 'eat', 'a', 'little', 'bit', 'you', 'can', 'get', 'them', 'some', 'little', 'puts', 'of', 'taking']
# Out of FOR LOOP
# ['they', 'can', 'eate', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Incorrect token is :  ['eate', 'biger']
# Words mispelled :  ['eate', 'biger']
# Error Index :  2 : eate
# Candidates with minimum edit distance : ['hate', 'Date', 'mate', 'late', 'eat', 'eats', 'Gate', 'Tate', 'gate', 'ate', 'date']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : eate
# Previous Error value : can
# Bi-gram words : can hate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : hate
# Corrected sentence: ['they', 'can', 'hate', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can Date
# prob for each bigram: 0.0
# Corrected word with high bigram probability : hate
# Corrected sentence: ['they', 'can', 'hate', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can mate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : hate
# Corrected sentence: ['they', 'can', 'hate', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can late
# prob for each bigram: 0.0
# Corrected word with high bigram probability : hate
# Corrected sentence: ['they', 'can', 'hate', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can eat
# prob for each bigram: 0.0196078431372549
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can eats
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can Gate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can Tate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can gate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can ate
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Previous Error value : can
# Bi-gram words : can date
# prob for each bigram: 0.0
# Corrected word with high bigram probability : eat
# Corrected sentence: ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'biger']
# Out of FOR LOOP
# Error Index :  10 : biger
# Candidates with minimum edit distance : ['bigger']
# in ELSE condition NO Candidates :
# ['they', 'can', 'eat', 'some', 'meal', 'when', 'they', 'get', 'a', 'little', 'bigger']
# ['we', 'give', 'them', 'some', 'fating', 'food', 'called', 'Nomber', '2']
# Incorrect token is :  ['fating', 'Nomber']
# Words mispelled :  ['fating', 'Nomber']
# Error Index :  4 : fating
# Candidates with minimum edit distance : ['Racing', 'sting', 'saying', 'racing', 'beating', 'taking', 'waiting', 'making', 'having', 'frying', 'waving', 'flying', 'farming', 'laying', 'Waiting']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : fating
# Previous Error value : some
# Bi-gram words : some Racing
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some sting
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some saying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some racing
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some beating
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some taking
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some waiting
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some making
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some having
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some frying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some waving
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some flying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some farming
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some laying
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Previous Error value : some
# Bi-gram words : some Waiting
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Racing
# Corrected sentence: ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Nomber', '2']
# Out of FOR LOOP
# Error Index :  7 : Nomber
# Candidates with minimum edit distance : ['Number']
# in ELSE condition NO Candidates :
# ['we', 'give', 'them', 'some', 'Racing', 'food', 'called', 'Number', '2']
# ['whe', 'you', 'wean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'wones']
# Incorrect token is :  ['whe', 'wean', 'wones']
# Words mispelled :  ['whe', 'wean', 'wones']
# Error Index :  0 : whe
# Candidates with minimum edit distance : ['he', 'we', 'The', 'she', 'She', 'why', 'who', 'when', 'the']
# in IF condition Greater Candidate :
# in ELSE condition - Unigram : whe
# Corrected word with high unigram probability : the
# ['the', 'you', 'wean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'wones']
# Error Index :  2 : wean
# Candidates with minimum edit distance : ['mean', 'wear', 'Jean']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : wean
# Previous Error value : you
# Bi-gram words : you mean
# prob for each bigram: 0.0
# Corrected word with high bigram probability : mean
# Corrected sentence: ['the', 'you', 'mean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'wones']
# Previous Error value : you
# Bi-gram words : you wear
# prob for each bigram: 0.0
# Corrected word with high bigram probability : mean
# Corrected sentence: ['the', 'you', 'mean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'wones']
# Previous Error value : you
# Bi-gram words : you Jean
# prob for each bigram: 0.0
# Corrected word with high bigram probability : mean
# Corrected sentence: ['the', 'you', 'mean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'wones']
# Out of FOR LOOP
# Error Index :  23 : wones
# Candidates with minimum edit distance : ['Jones', 'ones']
# in IF condition Greater Candidate :
# in IF condition - calculate Bigram : wones
# Previous Error value : little
# Bi-gram words : little Jones
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Jones
# Corrected sentence: ['the', 'you', 'mean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'Jones']
# Previous Error value : little
# Bi-gram words : little ones
# prob for each bigram: 0.0
# Corrected word with high bigram probability : Jones
# Corrected sentence: ['the', 'you', 'mean', 'that', 'is', 'take', 'them', 'from', 'their', 'mother', 'you', 'have', 'got', 'to', 'see', 'if', 'they', 'fight', 'if', 'there', 'is', 'any', 'little', 'Jones']
# Out of FOR LOOP
# ['fighting']
# Incorrect token is :  []
# Words mispelled :  []
# [['ROGER', 'THRUSH', 'page', '4'], ['I', 'have', 'four', 'in', 'my', 'Family', 'Dad', 'Mum', 'and', 'sister'], ['My', 'Dad', 'works', 'at', 'Melton'], ['My', 'sister', 'go', 'to', 'Tonbury'], ['My', 'Mum', 'goes', 'out', 'some', 'times'], ['I', 'go', 'to', 'Bridgebrook', 'i', 'go', 'out', 'some', 'times', 'on', 'Thursday', 'night', 'i', 'go', 'to', 'Youth', 'club'], ['On', 'Thursday', 'nights', 'I', 'go', 'bell', 'singing', 'on', 'Saturday', 'I', 'go', 'down', 'to', 'the', 'farm'], ['on', 'sunday', 'I', 'go', 'to', 'church'], ['I', 'go', 'to', 'bed', 'at', '10', 'a', 'clock', 'I', 'wash', 'TV', 'at', '5', '.', 'clock', 'I', 'live', 'in', 'a', 'house'], ['The', 'house', 'is', 'in', 'the', 'world'], ['I', 'live', 'at', 'Boat', 'Parva', 'it', 'is', 'near', 'Melton', 'and', 'Bridgebrook', 'and', 'Smallerden'], ['The', 'house', 'is', 'white', 'it', 'has', 'shone', 'up', 'the', 'front', 'it', 'is', 'the', 'first', 'from', 'Bridgebrook', 'and', 'the', 'sexton', 'from', 'Smallerden'], ['My', 'Mum', 'is', 'at', 'home', 'She', 'goes', 'to', 'the', 'shop', 'on', 'Friday', 'My', 'Dad', 'goes', 'to', 'work', 'at', 'Smallerden'], ['What', 'I', 'do', 'when', 'I', 'get', 'home', 'from', 'school'], ['On', 'Monday', 'I', 'sometimes', 'go', 'down', 'the', 'farm', 'in', 'the', 'night', 'I', 'wach', 'TV', 'there', 'is', 'ABC', 'and', 'TV'], ['I', 'like', 'TV'], ['We', 'call', 'English', 'ITV'], ['We', 'have', 'got', 'English', 'like', 'to', 'each', 'cow', 'Boys'], ['On', 'Tuesday', 'I', 'get', 'off', 'the', 'bus', 'and', 'some', 'times', 'in', 'the', 'night', 'I', 'go', 'to', 'the', 'Youth', 'colbe'], ['I', 'like', 'to', 'each', 'TV'], ['there', 'is', 'a', 'lot', 'of', 'things', 'on', 'TV'], ['I', 'wach', 'it', 'each', 'night'], ['I', 'thing', 't', 'is', 'good', 'but', 'people', 'say', 'it', 'gives', 'us', 'squeak', 'iyes'], ['The', 'Murder', 'Car'], ['1', 'night', 'when', 'it', 'was', 'dark', 'about', '12', "o'clock", 'a', 'man', 'was', 'tock', 'down', 'by', 'a', 'car'], ['The', 'body', 'was', 'found', 'a', '7', "o'clock", 'in', 'the', 'morning'], ['The', 'name', 'of', 'the', 'man', 'who', 'was', 'kill', 'was', 'Jack', 'robins', 'he', 'has', 'black', 'hair', 'brown', 'eyes', 'blue', 'Jacket', 'and', 'blue', 'beans'], ['No', 'one', 'see', 'the', 'car'], ['there', 'had', 'been', 'a', 'lot', 'of', 'people', 'tock', 'down', 'by', 'a', 'car', 'so', 'they', 'call', 'it', 'the', 'murder', 'car'], ['The', 'Police', 'cam', 'out', 'to', 'look', 'for', 'the', 'car'], ['The', 'other', 'cars', 'were', 'black', 'so', 'one', 'of', 'the', 'other', 'people', 'said'], ['The', 'murder', 'man', 'has', 'a', 'black', 'heard', 'The', 'next', 'day', 'one', 'of', 'the', 'policemen', 'were', 'killed', 'the', 'next', 'day', 'they', 'found', 'the', 'car', 'over', 'the', 'hill', 'the', 'was', 'the', 'man', 'near', 'it', 'he', 'was', 'dead'], ['I', 'kissed', 'a', 'girl', 'one', 'night', 'Here', 'iyes', 'were', 'Morning', 'blue', 'She', 'said', 'to', 'do', 'you', 'love', 'me', 'Of', 'course', 'of', 'course', 'I', 'do'], ['well', 'singing'], ['When', 'you', 'start', 'tell', 'singing', 'you', 'have', 'ring', 'a', 'bell', 'be', 'for', 'you', 'can', 'do', 'any', 'thing', 'as'], ['It', 'takes', 'a', 'lot', 'to', 'ring', 'a', 'bell', 'on', 'the', 'role', 'there', 'is', 'a', 'silly'], ['Of', 'the', 'bell', 'there', 'is', 'a', 'week'], ['the', 'feel', 'has', 'the', 'role', 'on', 'it', 'some', 'silly', 'are', 'green', 'and', 'the', 'other', 'are', 'red', 'white', 'and', 'blue'], ['When', 'you', 'can', 'ring'], ['You', 'have', 'to', 'ring', 'round', 'that', 'is', 'when', 'you', 'go', '35', 'when', 'you', 'can', 'don', 'that'], ['You', 'rings', 'like', 'this'], ['these', 'are', 'the', 'names', 'of', 'them', 'again', 'hunt', 'plan', 'Bob', 'Grandsire', 'double'], ['handsome', 'drives', 'it', 'takes', 'a', 'long', 'time', 'to', 'ring', 'them'], ['I', 'have', 'been', 'singing', 'a', 'long', 'time', 'we', 'go', 'to', 'Smallerden', 'and', 'Oakwell', 'and', 'Guildwell', 'we', 'will', 'we', 'go ...

# %%
# ** this and the previous cell contain mostly duplicate code - better to build both arrays at once! (-1)

is_misspelled_test = []
test_set = [d.text for d in test]
#is_misspelled_train=correct(train_set.split(" "))
Words_mispelled2=[]
#print("Words mispelled : ", is_misspelled_train)
for sentence in range(len(test_set)):
    s=test_set[sentence]
    line = s.rstrip('\r\n').replace(".","").strip()
    #print(line)
    if len(line) != 0:
        Words_mispelled2.append(list(read_sentence(line).tokens_corrected()))

#print(Words_mispelled2)

# %%
Accuracy_count = 0
for i in range(len(Words_mispelled1)):
    #print("Mystatement:",i,":",Words_mispelled1[i])
    #print("Comparestatement:",i,":",Words_mispelled2[i])
    
    # ** you're calculating sentence accuracy, not word accuracy! (-5)
    # ** you need to loop over the words in each sentence also...
    if(Words_mispelled1[i]==Words_mispelled2[i]):
        Accuracy_count+=1
        #print(Accuracy_count)
Accuracy=( Accuracy_count/len(Words_mispelled1))*100
print( Accuracy)
# Out:
# 24.175824175824175

# %% [markdown]
# Notice that your system currently corrects many words that do not need correction, the following code detects all the words that are in the test but not the training set and if they are errors or not:

# %%
# True spelling mistakes
true_positives = []
# Correctly spelled but unrecognized words
false_positives = []
false_negatives = []

for sentence in test:
    for word in sentence.tokens_with_errors():
        if word not in all_words:
            if word in sentence.errors():
                true_positives.append(word)
            else:
                false_positives.append(word)
        
        else:
            if word in sentence.errors():
                false_negatives.append(word)

                
print(len(true_positives))
print(len(false_positives))
print(len(false_negatives))
# Out:
# 72
# 88
# 32

# %% [markdown]
# ## **Task 5**:
# Using an SVM (see Lab 3) write a classifier that classifies a novel word as a misspelling or a new word based on the following features
#
# * The minimum edit distance to the nearest known English word
# * Whether it starts with a capital
# * Whether it is all in capitals
# * One other feature of your choice

# %%
def ed(token):
    ed = []
    for t in all_words:
        ed.append(edit_distance(token, t))
    min_ed = min(ed)
    return min_ed

def init_cap(token):
    
    if(token[0].isupper()):
        return 1
    else:
        return 0

def all_caps(token):
   
    if(all(word[0].isupper() for word in token)):
        return 1
    else:
        return 0 

# ** Your feature is the same as all_caps! (0/5)
def my_feature(token):
    # ** NOTE: `... for word in token` iterates over the CHARACTERS of token 
    # **  (ie: the variable `word` is a single character string)
    if (any(word[0].isupper() for word in token)):
        return 1
    else:
        return 0
    
X = [[ed(token), init_cap(token), all_caps(token), my_feature(token)] 
     for token in true_positives + false_positives]
y = [1] * len(true_positives) + [0] * len(false_positives)

from sklearn import svm

svc = svm.SVC()
svc_fit=svc.fit(X, y)
print(svc_fit)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## **Task 6**:
# Using the `cross_validation` methods from Scikit Learn (covered in Lab 4) perform 10-fold cross validation and report your precision, recall and F-Measure.

# %%
from sklearn import cross_validation
scores = cross_validation.cross_val_score(svc_fit, X, y, cv=10)

# ** these are results on the training data, not from cross validation!! (-10)
precision=len(true_positives)/(len(true_positives)+len(false_positives))
print(precision)
recall=len(true_positives)/(len(true_positives)+len(false_negatives))
print(recall)
F_Measure=2*precision*recall/(precision+recall)
print(F_Measure)
# Out:
# 0.45
# 0.6923076923076923
# 0.5454545454545455
